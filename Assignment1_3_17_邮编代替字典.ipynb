# %% [markdown]
# # <font color = '#e64626'>Assignment 1</font>

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import geocoder
import re
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set(style="white")
sns.set_context("notebook",
                rc={"xtick.labelsize": 12,
                    "ytick.labelsize": 12,
                    "axes.labelsize": 12,
                    "axes.titlesize": 15,
                    "legend.fontsize": 12})

# %% [markdown]
# # 1. 数据概述

# %%
A2B = pd.read_csv("A2B_Fare_Lookup.csv")
A2B.head()
# Out:
#                            partitionKey                    user_pseudo_id  \
# 0  62988560-2b0f-11ed-aeba-d39c8d7719af  1546E396FBFD49E6ACCB9BCBA42DBFE7
# 1  51064c10-2cea-11ed-9a00-d5b713a64e81  1546E396FBFD49E6ACCB9BCBA42DBFE7
# 2  76a63b10-2dcb-11ed-9a00-d5b713a64e81  1546E396FBFD49E6ACCB9BCBA42DBFE7
# 3  5b83c8b9-e7eb-479e-a7fa-4e9c2a110036  1546E396FBFD49E6ACCB9BCBA42DBFE7
# 4  bb0e3a30-2e95-11ed-9a00-d5b713a64e81  1546E396FBFD49E6ACCB9BCBA42DBFE7
#
#                  createdAt                                       startAddress  \
# 0  2022-09-03 08:34:19.703         2 Seaview Ave, Newport NSW 2106, Australia
# 1  2022-09-05 17:14:01.170      181 Lawson St, Darlington NSW 2008, Australia
# 2  2022-09-06 20:05:41.060     17 Millman Rd, Spring Farm NSW 2570, Australia
# 3  2022-10-23 16:41:09.086        6/73 Albert St, Revesby NSW 2212, Australia
# 4  2022-09-07 20:13:34.166  15 Warrigal St, Gregory Hills NSW 2557, Australia
#
#                                           endAddress  tripEstimate  BookingID  \
# 0  Sydney Airport DOM T2 Drop-Off, Sydney Airport...        126.00        NaN
# 1  Sydney Airport DOM T2 Drop-Off, Sydney Airport...         30.66        NaN
# 2  Sydney Airport DOM T2 Drop-Off, Sydney Airport...        158.76        NaN
# 3  Sydney Airport DOM T2 Drop-Off, Sydney Airport...         68.99        NaN
# 4  Sydney Airport DOM T2 Drop-Off, Sydney Airport...        160.65        NaN
#
#   BookingCreatedTime  PickUp_Latitude  PickUp_Longitude  DropOff_Latitude  \
# 0                NaN              NaN               NaN               NaN
# 1                NaN              NaN               NaN               NaN
# 2                NaN              NaN               NaN               NaN
# 3                NaN              NaN               NaN               NaN
# 4                NaN              NaN               NaN               NaN
#
#    DropOff_Longitude DispatchStatus
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN

# %%
A2B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153633 entries, 0 to 1153632
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   partitionKey        1153633 non-null  object
#  1   user_pseudo_id      1153633 non-null  object
#  2   createdAt           1153633 non-null  object
#  3   startAddress        1153415 non-null  object
#  4   endAddress          1153535 non-null  object
#  5   tripEstimate        1153633 non-null  float64
#  6   BookingID           521373 non-null   float64
#  7   BookingCreatedTime  521373 non-null   object
#  8   PickUp_Latitude     521373 non-null   float64
#  9   PickUp_Longitude    521373 non-null   float64
#  10  DropOff_Latitude    521371 non-null   float64
#  11  DropOff_Longitude   521371 non-null   float64
#  12  DispatchStatus      521373 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 114.4+ MB

# %%
raw = A2B

# %%
raw["DispatchStatus"].value_counts()
# Out:
# Completed       340009
# NotCompleted    181364
# Name: DispatchStatus, dtype: int64

# %% [markdown]
# # 2. 质量分析及数据预处理

# %% [markdown]
# ## 2.1 去重

# %% [markdown]
# ### 2.1.1 唯一字段去重

# %%
# 查看是否有全部重复的记录
raw.duplicated(keep=False).sum()
# Out:
# 0

# %% [markdown]
# 数据集中没有完全重复的记录。
# 接下来对一些唯一字段进行查重，判断是否需要处理。
# #### partitionKey

# %%
print("{:.2f}% duplicated records in partitionKey.".format(((len(raw) - raw["partitionKey"].nunique()) / len(raw) * 100)))
# Out:
# 0.25% duplicated records in partitionKey.

# %% [markdown]
# 用户预订出租车的流程大致为：
# 1. 进入LookUp系统（获得唯一partitionKey）；
# 2. 进入Booking系统（获得唯一BookingID）；
# 3. 中止预订或完成预订。
#
# 带有重复partitionKey的记录占比并不多，仅有0.25%。  通过观察，带有重复partitionKey的用户，都有多条不重复的BookingID，意味着用户可能在第一次进入booking后，退回了lookup阶段，但并未退出app，而是又发起了第二次booking（甚至第三、四次）。因此，partitionKey理论上也可以存在重复记录。
# 然而，以上的情景仅为推测。若按照此逻辑推断，多次booking记录若按时间排序，则应该要么全部是未完成状态，要么只有最新一条记录是完成状态。而数据集中除开这两种情况外，还有其他的情景存在。

# %%
raw[raw.duplicated(subset=["partitionKey"], keep=False)].sort_values(by=["partitionKey","BookingCreatedTime"]).head(20)
# Out:
#                                  partitionKey  \
# 671353   000bafa0-2f6d-11ed-aeba-d39c8d7719af
# 986147   000bafa0-2f6d-11ed-aeba-d39c8d7719af
# 980060   0024cd00-4f16-11ed-8cc4-f1bd638415f1
# 980059   0024cd00-4f16-11ed-8cc4-f1bd638415f1
# 896659   0056add0-4f97-11ed-9661-47dabcf94230
# 1103082  0056add0-4f97-11ed-9661-47dabcf94230
# 1002248  00738720-46f0-11ed-9661-47dabcf94230
# 710730   00738720-46f0-11ed-9661-47dabcf94230
# 681402   00934800-484c-11ed-9661-47dabcf94230
# 683459   00934800-484c-11ed-9661-47dabcf94230
# 1035836  009d9410-4903-11ed-8cc4-f1bd638415f1
# 764580   009d9410-4903-11ed-8cc4-f1bd638415f1
# 762554   009fe680-4c4f-11ed-9661-47dabcf94230
# 1026942  009fe680-4c4f-11ed-9661-47dabcf94230
# 1042128  00a8efa0-3584-11ed-9a00-d5b713a64e81
# 1042127  00a8efa0-3584-11ed-9a00-d5b713a64e81
# 1042993  00ae0340-3585-11ed-9992-2bb9650dd4cf
# 780107   00ae0340-3585-11ed-9992-2bb9650dd4cf
# 797002   00c61cf0-2e23-11ed-9a00-d5b713a64e81
# 1047242  00c61cf0-2e23-11ed-9a00-d5b713a64e81
#
#                            user_pseudo_id                createdAt  \
# 671353   EEEB8EA50CF946A383580FA06868EA7D  2022-09-08 21:54:31.706
# 986147   EEEB8EA50CF946A383580FA06868EA7D  2022-09-08 21:54:31.706
# 980060   7B4D91163B174E27925EA76313763DA2  2022-10-19 05:52:22.866
# 980059   7B4D91163B174E27925EA76313763DA2  2022-10-19 05:52:22.866
# 896659   0881df095b1a6de4b06e97be0adc31b5  2022-10-19 21:15:48.270
# 1026942        151.251972        -33.858819         151.207423   NotCompleted
# 1042128        145.163879        -37.954005         145.151291   NotCompleted
# 1042127        145.163879        -37.954005         145.151291   NotCompleted
# 1042993        151.206513        -33.830148         151.236357   NotCompleted
# 780107         151.206513        -33.830148         151.236357      Completed
# 797002         151.201680        -33.874856         151.199512      Completed
# 1047242        151.201680        -33.874856         151.199512   NotCompleted

# %%
idx = raw["partitionKey"].value_counts() > 1
partition_duplicated = pd.DataFrame(dict(Numbers=raw["partitionKey"].value_counts()[idx]))
partition_duplicated
# Out:
#                                       Numbers
# bd3b05c0-51f6-11ed-8cc4-f1bd638415f1        8
# 18414ee0-584e-11ed-8b11-1f5b62fad19f        5
# 5fdbdce0-30e2-11ed-9992-2bb9650dd4cf        5
# f392dde0-4149-11ed-8cc4-f1bd638415f1        5
# d23e2580-2d82-11ed-aeba-d39c8d7719af        5
# ...                                       ...
# d453dfe0-35b6-11ed-9a00-d5b713a64e81        2
# 253aa540-300a-11ed-9a00-d5b713a64e81        2
# 72fdece0-3408-11ed-9a00-d5b713a64e81        2
# eece6250-3bf6-11ed-9a00-d5b713a64e81        2
# 1d2f8cf0-4610-11ed-8cc4-f1bd638415f1        2
#
# [2704 rows x 1 columns]

# %% [markdown]
# 通过观察，数据集中patitionKey重复字段可分为以下几种情况：
# * 情况1：全部未完成
# * 情况2：只有最后订单完成
# * 情况3：超过一个订单完成
# * 情况4：一个前序订单完成而其他订单未完成
#
# 情况1&2符合用户的预订流程逻辑，故不做处理。情况3&4，并不符合用户使用app的流程逻辑，推测可能是系统问题导致，因此考虑直接删除对应partitionKey的全部记录。

# %%
subset = raw[raw.duplicated(subset=["partitionKey"], keep=False)].sort_values(by=["partitionKey","BookingCreatedTime"])[["partitionKey", "BookingCreatedTime", "DispatchStatus"]]
subset
# Out:
#                                  partitionKey       BookingCreatedTime  \
# 671353   000bafa0-2f6d-11ed-aeba-d39c8d7719af  2022-09-08 21:55:38.846
# 986147   000bafa0-2f6d-11ed-aeba-d39c8d7719af  2022-09-08 21:55:59.770
# 980060   0024cd00-4f16-11ed-8cc4-f1bd638415f1  2022-10-19 05:56:04.786
# 980059   0024cd00-4f16-11ed-8cc4-f1bd638415f1  2022-10-19 05:56:25.120
# 896659   0056add0-4f97-11ed-9661-47dabcf94230  2022-10-19 21:16:07.230
# ...                                       ...                      ...
# 1074651  ffd59e90-404e-11ed-8cc4-f1bd638415f1  2022-09-30 09:32:55.196
# 764322   ffe10800-4145-11ed-9661-47dabcf94230  2022-10-01 15:00:58.350
# 764323   ffe10800-4145-11ed-9661-47dabcf94230  2022-10-01 15:01:02.623
# 978885   fffde800-3c25-11ed-9a00-d5b713a64e81  2022-09-25 02:29:52.510
# 978886   fffde800-3c25-11ed-9a00-d5b713a64e81  2022-09-25 02:30:17.373
#
#         DispatchStatus
# 671353       Completed
# 986147    NotCompleted
# 980060    NotCompleted
# 980059    NotCompleted
# 896659       Completed
# ...                ...
# 1074651   NotCompleted
# 764322       Completed
# 764323       Completed
# 978885    NotCompleted
# 978886    NotCompleted
#
# [5577 rows x 3 columns]

# %%
for key in partition_duplicated.index:
    temp = subset[subset["partitionKey"] == key]
    if len(temp) - temp["DispatchStatus"].str.contains("NotCompleted").sum() == 0:  # 情景1
        partition_duplicated.loc[key, "Scenario"] = 1
    elif len(temp) - temp["DispatchStatus"].str.contains("NotCompleted").sum() == 1 and temp["DispatchStatus"].values[-1] == "Completed":  # 情景2
        partition_duplicated.loc[key, "Scenario"] = 2
    elif len(temp) - temp["DispatchStatus"].str.contains("NotCompleted").sum() > 1:  # 情景3
        partition_duplicated.loc[key, "Scenario"] = 3
    elif temp["DispatchStatus"].values[-1] == "NotCompleted" and len(temp) - temp["DispatchStatus"].str.contains("NotComplete").sum() != 0:  # 情景4
        partition_duplicated.loc[key, "Scenario"] = 4

# %%
len(partition_duplicated) - partition_duplicated["Scenario"].notnull().sum()
# Out:
# 0

# %%
partition_duplicated["Scenario"].value_counts().sort_index()
# Out:
# 1.0    1028
# 2.0     946
# 3.0     200
# 4.0     530
# Name: Scenario, dtype: int64

# %%
partition_duplicated
# Out:
#                                       Numbers  Scenario
# bd3b05c0-51f6-11ed-8cc4-f1bd638415f1        8       1.0
# 18414ee0-584e-11ed-8b11-1f5b62fad19f        5       1.0
# 5fdbdce0-30e2-11ed-9992-2bb9650dd4cf        5       4.0
# f392dde0-4149-11ed-8cc4-f1bd638415f1        5       4.0
# d23e2580-2d82-11ed-aeba-d39c8d7719af        5       2.0
# ...                                       ...       ...
# d453dfe0-35b6-11ed-9a00-d5b713a64e81        2       2.0
# 253aa540-300a-11ed-9a00-d5b713a64e81        2       4.0
# 72fdece0-3408-11ed-9a00-d5b713a64e81        2       2.0
# eece6250-3bf6-11ed-9a00-d5b713a64e81        2       2.0
# 1d2f8cf0-4610-11ed-8cc4-f1bd638415f1        2       2.0
#
# [2704 rows x 2 columns]

# %%
dropindex = raw["partitionKey"].isin(partition_duplicated[(partition_duplicated["Scenario"]==3) | (partition_duplicated["Scenario"]==4)].index.values)
raw = raw[~dropindex]

# %%
raw.head()
# Out:
#                            partitionKey                    user_pseudo_id  \
# 0  62988560-2b0f-11ed-aeba-d39c8d7719af  1546E396FBFD49E6ACCB9BCBA42DBFE7
# 1  51064c10-2cea-11ed-9a00-d5b713a64e81  1546E396FBFD49E6ACCB9BCBA42DBFE7
# 2  76a63b10-2dcb-11ed-9a00-d5b713a64e81  1546E396FBFD49E6ACCB9BCBA42DBFE7
# 3  5b83c8b9-e7eb-479e-a7fa-4e9c2a110036  1546E396FBFD49E6ACCB9BCBA42DBFE7
# 4  bb0e3a30-2e95-11ed-9a00-d5b713a64e81  1546E396FBFD49E6ACCB9BCBA42DBFE7
#
#                  createdAt                                       startAddress  \
# 0  2022-09-03 08:34:19.703         2 Seaview Ave, Newport NSW 2106, Australia
# 1  2022-09-05 17:14:01.170      181 Lawson St, Darlington NSW 2008, Australia
# 2  2022-09-06 20:05:41.060     17 Millman Rd, Spring Farm NSW 2570, Australia
# 3  2022-10-23 16:41:09.086        6/73 Albert St, Revesby NSW 2212, Australia
# 4  2022-09-07 20:13:34.166  15 Warrigal St, Gregory Hills NSW 2557, Australia
#
#                                           endAddress  tripEstimate  BookingID  \
# 0  Sydney Airport DOM T2 Drop-Off, Sydney Airport...        126.00        NaN
# 1  Sydney Airport DOM T2 Drop-Off, Sydney Airport...         30.66        NaN
# 2  Sydney Airport DOM T2 Drop-Off, Sydney Airport...        158.76        NaN
# 3  Sydney Airport DOM T2 Drop-Off, Sydney Airport...         68.99        NaN
# 4  Sydney Airport DOM T2 Drop-Off, Sydney Airport...        160.65        NaN
#
#   BookingCreatedTime  PickUp_Latitude  PickUp_Longitude  DropOff_Latitude  \
# 0                NaN              NaN               NaN               NaN
# 1                NaN              NaN               NaN               NaN
# 2                NaN              NaN               NaN               NaN
# 3                NaN              NaN               NaN               NaN
# 4                NaN              NaN               NaN               NaN
#
#    DropOff_Longitude DispatchStatus
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN

# %% [markdown]
# #### BookingID
# BookingID没有任何重复记录。

# %%
bks = raw[raw["BookingID"].notnull()]
len(bks)  == bks["BookingID"].nunique()
# Out:
# True

# %% [markdown]
# ### 2.1.2 逻辑判断去重
# 在唯一字段的检验中，我们已经剔除了不符合流程逻辑的partitionKey重复记录，并保留了符合逻辑且反应现实的重复记录。但是基于观察，我们不难发现数据集中还存在一些其他不符合逻辑的重复记录，这些记录通过对单一的唯一字段进行检验无法找出，需要多变量联合筛选。
# 具体来说，尽管从全数据集来看，LookUp时间和Booking时间是可以重复的字段。但是对于同一个用户来说，在同一时间进行多次查询或预订显然是不符合逻辑的。因此在此部分中，我们考虑将用户id和两个时间字段进行交叉检验，并对存在逻辑问题的记录进行清理。

# %% [markdown]
# #### user_pseudo_id & createdAt
# 通过筛选，将同一用户、同一时间但却有不重复partitionKey的记录挑选出来，一共24条。显然，同一用户不可能在完全相同的时间里提出多次不同（partitionKey不同）的lookup请求，因此考虑将重复记录删除，保留一条记录。若有booking记录，则保留带有booking的记录。

# %%
# 查看同一用户同一时间有LookUp记录的数量
temp = raw[raw.duplicated(subset=["user_pseudo_id", "createdAt"], keep=False)].sort_values(by=["user_pseudo_id"])  # 选出同一用户同一时间的LookUp记录
key = temp["partitionKey"].value_counts()[temp["partitionKey"].value_counts() == 1].index.values  # 其中有一部分是重复partitionKey的记录，已在上面完成处理，找出不带有重复partitionKey的记录的key
idx = temp["partitionKey"].isin(key)
temp = temp[idx].sort_values(by=["user_pseudo_id","BookingID"])
# 一共有24条记录

# %%
temp
# Out:
#                                 partitionKey  \
# 302517  1f702ef0-2fe7-11ed-aeba-d39c8d7719af
# 302337  1f702ef0-2fe7-11ed-9a00-d5b713a64e81
# 357284  4a73a540-4dac-11ed-9661-47dabcf94230
# 357193  4a735720-4dac-11ed-8cc4-f1bd638415f1
# 218292  7c906290-421f-11ed-9661-47dabcf94230
# 218491  7c90d7c0-421f-11ed-8cc4-f1bd638415f1
# 318066  6054f7f0-5596-11ed-bafc-eb69a13397eb
# 317751  6054f7f3-5596-11ed-bafc-eb69a13397eb
# 397344  7315b5d0-3af3-4d74-bc8e-aba9d365a692
# 854638  557 Little Lonsdale St, Melbourne VIC 3000, Au...         21.32
# 591485  557 Little Lonsdale St, Melbourne VIC 3000, Au...         21.21
#
#          BookingID       BookingCreatedTime  PickUp_Latitude  \
# 302517         NaN                      NaN              NaN
# 302337         NaN                      NaN              NaN
# 357284         NaN                      NaN              NaN
# 357193         NaN                      NaN              NaN
# 218292         NaN                      NaN              NaN
# 218491         NaN                      NaN              NaN
# 318066         NaN                      NaN              NaN
# 317751         NaN                      NaN              NaN
# 397344         NaN                      NaN              NaN
# 397462         NaN                      NaN              NaN
# 858629  32339190.0  2022-10-14 22:45:42.750       -27.446814
# 466297         NaN                      NaN              NaN
# 175484         NaN                      NaN              NaN
# 175468         NaN                      NaN              NaN
# 504176         NaN                      NaN              NaN
# 504459         NaN                      NaN              NaN
# 445962         NaN                      NaN              NaN
# 446079         NaN                      NaN              NaN
# 226216         NaN                      NaN              NaN
# 226258         NaN                      NaN              NaN
# 803004  31863211.0  2022-09-24 12:39:47.290       -37.929680
# 426805         NaN                      NaN              NaN
# 854638  31345098.0  2022-09-01 17:40:19.096       -37.810493
# 591485         NaN                      NaN              NaN
#
#         PickUp_Longitude  DropOff_Latitude  DropOff_Longitude DispatchStatus
# 302517               NaN               NaN                NaN            NaN
# 302337               NaN               NaN                NaN            NaN
# 357284               NaN               NaN                NaN            NaN
# 357193               NaN               NaN                NaN            NaN
# 218292               NaN               NaN                NaN            NaN
# 218491               NaN               NaN                NaN            NaN
# 318066               NaN               NaN                NaN            NaN
# 317751               NaN               NaN                NaN            NaN
# 397344               NaN               NaN                NaN            NaN
# 397462               NaN               NaN                NaN            NaN
# 858629        153.166768        -27.434098         153.156709      Completed
# 466297               NaN               NaN                NaN            NaN
# 175484               NaN               NaN                NaN            NaN
# 175468               NaN               NaN                NaN            NaN
# 504176               NaN               NaN                NaN            NaN
# 504459               NaN               NaN                NaN            NaN
# 445962               NaN               NaN                NaN            NaN
# 446079               NaN               NaN                NaN            NaN
# 226216               NaN               NaN                NaN            NaN
# 226258               NaN               NaN                NaN            NaN
# 803004        145.104307        -37.912491         145.030843      Completed
# 426805               NaN               NaN                NaN            NaN
# 854638        144.988051        -37.813301         144.955358      Completed
# 591485               NaN               NaN                NaN            NaN

# %%
keep = temp.drop_duplicates(subset=["createdAt"], inplace=False, keep="first").index  # 首先选出在数据集里要留下的index
drop = [idx for idx in temp.index]  # 用for循环把重复集中要剔除的index选出来
for idx in drop:
    if idx in keep:
        drop.remove(idx)
drop
# Out:
# [302337,
#  357193,
#  218491,
#  317751,
#  397462,
#  466297,
#  175468,
#  504459,
#  446079,
#  226258,
#  426805,
#  591485]

# %%
raw.drop(drop, axis=0,inplace=True)

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1152083 entries, 0 to 1153632
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   partitionKey        1152083 non-null  object
#  1   user_pseudo_id      1152083 non-null  object
#  2   createdAt           1152083 non-null  object
#  3   startAddress        1151865 non-null  object
#  4   endAddress          1151985 non-null  object
#  5   tripEstimate        1152083 non-null  float64
#  6   BookingID           519835 non-null   float64
#  7   BookingCreatedTime  519835 non-null   object
#  8   PickUp_Latitude     519835 non-null   float64
#  9   PickUp_Longitude    519835 non-null   float64
#  10  DropOff_Latitude    519833 non-null   float64
#  11  DropOff_Longitude   519833 non-null   float64
#  12  DispatchStatus      519835 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 123.1+ MB

# %% [markdown]
# #### user_pseudo_id & BookingCreatedTime
# BookingCreatedTime没有不合逻辑的重复值，说明booking子集的数据质量较好。

# %%
bks = raw[raw["BookingID"].notnull()]  # 选出booking子集
len(bks[bks.duplicated(subset=["user_pseudo_id", "BookingCreatedTime"], keep=False)].sort_values(by=["user_pseudo_id"]))
# Out:
# 0

# %% [markdown]
# ## 2.2 缺失值处理

# %% [markdown]
# 首先将数据集分为两个子集：查询集（lk_subset）和预订集（bk_subset）。显然，按照流程逻辑，查询集中BookingID及其后序字段均为NAN，而预订集中所有字段应都有对应的值。

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1152083 entries, 0 to 1153632
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   partitionKey        1152083 non-null  object
#  1   user_pseudo_id      1152083 non-null  object
#  2   createdAt           1152083 non-null  object
#  3   startAddress        1151865 non-null  object
#  4   endAddress          1151985 non-null  object
#  5   tripEstimate        1152083 non-null  float64
#  6   BookingID           519835 non-null   float64
#  7   BookingCreatedTime  519835 non-null   object
#  8   PickUp_Latitude     519835 non-null   float64
#  9   PickUp_Longitude    519835 non-null   float64
#  10  DropOff_Latitude    519833 non-null   float64
#  11  DropOff_Longitude   519833 non-null   float64
#  12  DispatchStatus      519835 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 123.1+ MB

# %%
bk_subset = raw[raw["BookingID"].notnull()]
lk_subset = raw[raw["BookingID"].isnull()]
len(bk_subset) + len(lk_subset) == len(raw)
# Out:
# True

# %% [markdown]
# ### 2.2.1 查询集（LookUp Subset）

# %%
lk_subset.isnull().sum()
# Out:
# partitionKey               0
# user_pseudo_id             0
# createdAt                  0
# startAddress             114
# endAddress                48
# tripEstimate               0
# BookingID             632248
# BookingCreatedTime    632248
# PickUp_Latitude       632248
# PickUp_Longitude      632248
# DropOff_Latitude      632248
# DropOff_Longitude     632248
# DispatchStatus        632248
# dtype: int64

# %%
# 两集元素数量相加和两集并集的元素数量相等，所以起始点缺失和终点缺失互不重合
len(lk_subset[lk_subset["startAddress"].isnull() | lk_subset["endAddress"].isnull()]) == len(lk_subset[lk_subset["startAddress"].isnull()])+len(lk_subset[lk_subset["endAddress"].isnull()])
# Out:
# True

# %%
lk_subset[lk_subset["user_pseudo_id"]=="E447773A9F2B4902B8379C2C5D285B75"].sort_values("createdAt")
# Out:
#                                 partitionKey  \
# 579880  28d55780-3fc9-11ed-9a00-d5b713a64e81
# 346222  89be8920-439f-11ed-8cc4-f1bd638415f1
# 565603  7b0e64d0-4440-11ed-8cc4-f1bd638415f1
# 594705  b4d976c0-45d3-11ed-9661-47dabcf94230
# 398882  e98e4f70-464c-11ed-9661-47dabcf94230
# 225149  f0880be0-464c-11ed-9661-47dabcf94230
# 494888  7d95ec20-4687-11ed-8cc4-f1bd638415f1
# 458829  d4064740-4b0e-11ed-9661-47dabcf94230
# 597196  c26d25e0-4b85-11ed-9661-47dabcf94230
# 565983  bad24250-4d44-11ed-8cc4-f1bd638415f1
# 314455  15 Hawthorn Rd, Caulfield North VIC 3161, Aust...         42.53
# 195868           13 Izett St, Prahran VIC 3181, Australia         71.61
# 235903  15 State Route 19, Caulfield North VIC 3161, A...         58.70
# 373998  15 State Route 19, Caulfield North VIC 3161, A...         33.60
# 542827           13 Izett St, Prahran VIC 3181, Australia         19.74
# 555822  15 Hawthorn Rd, Caulfield North VIC 3161, Aust...         22.16
# 512244         2-4 Stud Rd, Dandenong VIC 3175, Australia         23.21
# 476787  25 Devira St, Dandenong North VIC 3175, Australia         24.57
# 240381      9 Memorial Dr, Noble Park VIC 3174, Australia         54.81
# 465265  25 Devira St, Dandenong North VIC 3175, Australia         25.62
# 531297     607 St Kilda Rd, Melbourne VIC 3004, Australia         20.90
#
#         BookingID BookingCreatedTime  PickUp_Latitude  PickUp_Longitude  \
# 579880        NaN                NaN              NaN               NaN
# 346222        NaN                NaN              NaN               NaN
# 565603        NaN                NaN              NaN               NaN
# 594705        NaN                NaN              NaN               NaN
# 398882        NaN                NaN              NaN               NaN
# 225149        NaN                NaN              NaN               NaN
# 494888        NaN                NaN              NaN               NaN
# 458829        NaN                NaN              NaN               NaN
# 597196        NaN                NaN              NaN               NaN
# 565983        NaN                NaN              NaN               NaN
# 496213        NaN                NaN              NaN               NaN
# 223044        NaN                NaN              NaN               NaN
# 216376        NaN                NaN              NaN               NaN
# 171679        NaN                NaN              NaN               NaN
# 149487        NaN                NaN              NaN               NaN
# 149420        NaN                NaN              NaN               NaN
# 314455        NaN                NaN              NaN               NaN
# 195868        NaN                NaN              NaN               NaN
# 235903        NaN                NaN              NaN               NaN
# 373998        NaN                NaN              NaN               NaN
# 542827        NaN                NaN              NaN               NaN
# 555822        NaN                NaN              NaN               NaN
# 512244        NaN                NaN              NaN               NaN
# 476787        NaN                NaN              NaN               NaN
# 240381        NaN                NaN              NaN               NaN
# 465265        NaN                NaN              NaN               NaN
# 531297        NaN                NaN              NaN               NaN
#
#         DropOff_Latitude  DropOff_Longitude DispatchStatus
# 579880               NaN                NaN            NaN
# 346222               NaN                NaN            NaN
# 565603               NaN                NaN            NaN
# 594705               NaN                NaN            NaN
# 398882               NaN                NaN            NaN
# 225149               NaN                NaN            NaN
# 494888               NaN                NaN            NaN
# 458829               NaN                NaN            NaN
# 597196               NaN                NaN            NaN
# 565983               NaN                NaN            NaN
# 496213               NaN                NaN            NaN
# 223044               NaN                NaN            NaN
# 216376               NaN                NaN            NaN
# 171679               NaN                NaN            NaN
# 149487               NaN                NaN            NaN
# 149420               NaN                NaN            NaN
# 314455               NaN                NaN            NaN
# 195868               NaN                NaN            NaN
# 235903               NaN                NaN            NaN
# 373998               NaN                NaN            NaN
# 542827               NaN                NaN            NaN
# 555822               NaN                NaN            NaN
# 512244               NaN                NaN            NaN
# 476787               NaN                NaN            NaN
# 240381               NaN                NaN            NaN
# 465265               NaN                NaN            NaN
# 531297               NaN                NaN            NaN

# %%
drop = lk_subset[lk_subset["startAddress"].isnull() | lk_subset["endAddress"].isnull()].index

# %%
raw.drop(drop, axis=0, inplace=True)

# %%
raw[raw["BookingID"].isnull()].isnull().sum()
# Out:
# partitionKey               0
# user_pseudo_id             0
# createdAt                  0
# startAddress               0
# endAddress                 0
# tripEstimate               0
# BookingID             632086
# BookingCreatedTime    632086
# PickUp_Latitude       632086
# PickUp_Longitude      632086
# DropOff_Latitude      632086
# DropOff_Longitude     632086
# DispatchStatus        632086
# dtype: int64

# %% [markdown]
# ### 2.2.2 预订集（Booking Subset）

# %%
bk_subset.isnull().sum()
# Out:
# partitionKey            0
# user_pseudo_id          0
# createdAt               0
# startAddress          104
# endAddress             50
# tripEstimate            0
# BookingID               0
# BookingCreatedTime      0
# PickUp_Latitude         0
# PickUp_Longitude        0
# DropOff_Latitude        2
# DropOff_Longitude       2
# DispatchStatus          0
# dtype: int64

# %% [markdown]
# #### DropOff Lat & Long
# 先看经纬度缺失

# %%
dropoff = bk_subset[bk_subset["DropOff_Latitude"].isnull() | bk_subset["DropOff_Longitude"].isnull()]
dropoff
# Out:
#                                 partitionKey  \
# 866815  b5d2440e-01c6-49c9-a3d3-4c4b96ff219c
# 943894  8389bde0-3b9d-11ed-9a00-d5b713a64e81
#
#                           user_pseudo_id                createdAt  \
# 866815  5294f665d8dc60866199af8d6668b748  2022-10-27 09:15:40.266
# 943894  135E9F3B2E7146BC8BEC8DA1BD450F08  2022-09-24 10:12:02.110
#
#                                              startAddress  \
# 866815        105 Cape St, Heidelberg VIC 3084, Australia
# 943894  723 State Route 15, Malvern East VIC 3145, Aus...
#
#                                               endAddress  tripEstimate  \
# 866815  27 Perth St, Heidelberg West VIC 3081, Australia         19.53
# 943894       8 Warner Ave, Ashburton VIC 3147, Australia         14.91
#
#          BookingID       BookingCreatedTime  PickUp_Latitude  \
# 866815  32644086.0  2022-10-27 09:15:46.640       -37.755553
# 943894  31859589.0  2022-09-24 10:12:13.406       -37.881228
#
#         PickUp_Longitude  DropOff_Latitude  DropOff_Longitude DispatchStatus
# 866815        145.066975               NaN                NaN      Completed
# 943894        145.090564               NaN                NaN      Completed

# %% [markdown]
# 因为有终点地址，可以对dropoff经纬度进行填补。

# %%
g = geocoder.arcgis("27 Perth St, Heidelberg West VIC 3081, Australia")
g.latlng
# Out:
# [-37.73524201369623, 145.04198174227122]

# %%
for idx in dropoff.index:
    endaddress = raw.loc[idx, "endAddress"]
    g = geocoder.arcgis(endaddress)
    lat, long = g.latlng[0], g.latlng[1]
    raw.loc[idx, "DropOff_Latitude"], raw.loc[idx,"DropOff_Longitude"] = lat, long

# %%
raw[raw["BookingID"].notnull()].isnull().sum()
# Out:
# partitionKey            0
# user_pseudo_id          0
# createdAt               0
# startAddress          104
# endAddress             50
# tripEstimate            0
# BookingID               0
# BookingCreatedTime      0
# PickUp_Latitude         0
# PickUp_Longitude        0
# DropOff_Latitude        0
# DropOff_Longitude       0
# DispatchStatus          0
# dtype: int64

# %% [markdown]
# #### startAddress & enAddress
# 接下来对这两个字段的缺失值用记录中的经纬度进行逆编码填补。

# %%
address_null_subset = bk_subset[bk_subset["startAddress"].isnull() | bk_subset["endAddress"].isnull()]
address_null_subset[['startAddress','endAddress']]=address_null_subset[['startAddress','endAddress']].astype(str)  # 将字段中的NAN转变成字符串nan，便于后续提取
address_null_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 632260 to 1148206
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   partitionKey        154 non-null    object
#  1   user_pseudo_id      154 non-null    object
#  2   createdAt           154 non-null    object
#  3   startAddress        154 non-null    object
#  4   endAddress          154 non-null    object
#  5   tripEstimate        154 non-null    float64
#  6   BookingID           154 non-null    float64
#  7   BookingCreatedTime  154 non-null    object
#  8   PickUp_Latitude     154 non-null    float64
#  9   PickUp_Longitude    154 non-null    float64
#  10  DropOff_Latitude    154 non-null    float64
#  11  DropOff_Longitude   154 non-null    float64
#  12  DispatchStatus      154 non-null    object
# dtypes: float64(6), object(7)
# memory usage: 16.8+ KB

# %%
for idx in address_null_subset.index:
    if (address_null_subset.loc[idx, 'startAddress']) == 'nan':
        g = geocoder.osm(address_null_subset.loc[idx, ['PickUp_Latitude', 'PickUp_Longitude']].to_list(), method='reverse')
        raw.loc[idx, 'startAddress'] = g.address
    else:
        g = geocoder.osm(address_null_subset.loc[idx, ['DropOff_Latitude', 'DropOff_Longitude']].to_list(), method='reverse')
        raw.loc[idx, 'endAddress'] = g.address

# %%
raw[raw["BookingID"].notnull()].isnull().sum()
# Out:
# partitionKey          0
# user_pseudo_id        0
# createdAt             0
# startAddress          0
# endAddress            0
# tripEstimate          0
# BookingID             0
# BookingCreatedTime    0
# PickUp_Latitude       0
# PickUp_Longitude      0
# DropOff_Latitude      0
# DropOff_Longitude     0
# DispatchStatus        0
# dtype: int64

# %% [markdown]
# 至此完成数据清洗工作。

# %%
washed = raw  # 给清洗后的df重新命名为washed
whole = washed.copy()  # 对washed进行复制，保留一份副本，之后的特征工程在whole df上进行
whole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1151921 entries, 0 to 1153632
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   partitionKey        1151921 non-null  object
#  1   user_pseudo_id      1151921 non-null  object
#  2   createdAt           1151921 non-null  object
#  3   startAddress        1151921 non-null  object
#  4   endAddress          1151921 non-null  object
#  5   tripEstimate        1151921 non-null  float64
#  6   BookingID           519835 non-null   float64
#  7   BookingCreatedTime  519835 non-null   object
#  8   PickUp_Latitude     519835 non-null   float64
#  9   PickUp_Longitude    519835 non-null   float64
#  10  DropOff_Latitude    519835 non-null   float64
#  11  DropOff_Longitude   519835 non-null   float64
#  12  DispatchStatus      519835 non-null   object
# dtypes: float64(6), object(7)
# memory usage: 155.3+ MB

# %% [markdown]
# # 3. 特征工程 & EDA

# %% [markdown]
# ## 3.1 地址类

# %%
# start_dict = {
#     "NSW": "NSW",
#     "QLD": "QLD",
#     "VIC": "VIC",
#     "WA": "WA",
#     "SA": "SA",
#     "TAS": "TAS",
#     "ACT": "ACT",
#     "NT": "NT",
    
    
#     "New South Wales": "NSW",
#     "Queensland": "QLD",
#     "Western Australia": "WA",
#     "Northern Territory": "NT",
#     "Tasmania": "TAS",
#     "Victoria": "VIC",
#     "South Australia": "SA",
    
#     "Gold Coast": "QLD",
#     "Nelly Bay": "QLD",
#     "Shute Harbour": "QLD",
#     "Sea World": "QLD",
#     "Redland": "QLD",
#     "Great Barrier": "QLD",
#     "Coral Sea": "QLD",
   
    
#     "RIVER BOULEVARD RICHMOND": "VIC",
#     "William St/Collins": "VIC",

# }
# whole["StartState"] = None
# for key in start_dict.keys():
#     whole.loc[whole["startAddress"].str.contains(key) & whole["StartState"].isnull(), "StartState"] = start_dict[key]

# %%
# start_dict = {
#     "NSW": ["NSW", "New South Wales"],
#     "QLD": ["QLD", "Queensland", "Gold Coast", "Nelly Bay", "Shute Harbour", "Sea World", "Redland"],
#     "SA": ["SA", "South Australia"],
#     "TAS": ["TAS", "Tasmania"],
#     "VIC": ["VIC", "RIVER BOULEVARD RICHMOND", "William St/Collins", "Victoria"],
#     "WA": ["WA", "Western Australia"],
#     "ACT": ["ACT"],
#     "NT": ["NT", "Northern Territory"],
#     "Coral Sea": ["Coral", "Great Barrier"]
# }
# for key in start_dict.keys():
#     for item in start_dict.get(key):
#         whole.loc[whole["startAddress"].str.contains(item), "StartState"] = key

# %%
# end_dict = {
#     "NSW": "NSW",
#     "QLD": "QLD",
#     "VIC": "VIC",
#     "WA": "WA",
#     "SA": "SA",
#     "TAS": "TAS",
#     "NT": "NT",
#     "ACT": "ACT", 

    
    
#     "New South Wales": "NSW",
#     "Queensland": "QLD",
#     "South Australia": "SA",
#     "Tasmania": "TAS",
#     "Victoria": "VIC",
#     "Northern Territory": "NT",
#     "Australian Capital Territory": "ACT",
#     "Western Australia": "WA",
    
    
    
#     "Canberra": "ACT",
#     "St Kilda Marina": "VIC",
#     "Gold Coast": "QLD",
#     "Terminal, Bilinga": "QLD",
#     "Tea Tree Bay": "QLD",
#     "Nelly Bay": "QLD",
#     "Shute Harbour": "QLD",
#     "Sea World": "QLD",
#     "Coral": "QLD",
#     "Great Barrier": "QLD",
#     "Redland": "QLD",
#     "Fitzwilliam St": "NSW",
#     "Byron Bay": "NSW",  

# }
# whole["EndState"] = None

# for key in end_dict.keys():
#     whole.loc[whole["endAddress"].str.contains(key) & whole["EndState"].isnull(), "EndState"] = end_dict[key]

# %%
# end_dict = {
#     "NSW": ["NSW", "New South Wales", "Fitzwilliam St", "Byron Bay"],
#     "QLD": ["QLD", "Queensland", "Gold Coast", "Terminal, Bilinga", "Tea Tree Bay", "Nelly Bay", "Shute Harbour", "Sea World", "Redland"],
#     "SA": ["SA", "South Australia"],
#     "TAS": ["TAS", "Tasmania"],
#     "VIC": ["VIC", "Victoria", "St Kilda Marina"],
#     "WA": ["WA", "Western Australia"],
#     "ACT": ["ACT", "Australian Capital Territory", "Canberra"],
#     "NT": ["NT", "Northern Territory"],
#     "Coral Sea": ["Coral", "Great Barrier"]
# }
# for key in end_dict.keys():
#     for item in end_dict.get(key):
#         whole.loc[whole["endAddress"].str.contains(item), "EndState"] = key

# %% [markdown]
# ### 3.1.1 邮编

# %% [markdown]
# 澳大利亚首都地区（ACT）：0200-0299，2600-2618，2900-2920
#
# 新南威尔士州（NSW）：1000-1999，2000-2599，2619-2899，2921-2999
#
# 北领地（NT）：0800-0899
#
# 昆士兰州（QLD）：4000-4999，9000-9999
#
# 南澳大利亚州（SA）：5000-5999，6000-6999
#
# 塔斯马尼亚州（TAS）： TAS: 7000-7999
#
# 维多利亚州（VIC）：3000-3999，8000-8999
#
# 西澳大利亚州（WA）：6000-6797，6800-6999

# %%
pattern = r'\b\d{4}\b'
re.findall(pattern,"Australia, Queensland, 23 Southport, Lawson 4561,8 St, 30 6405 65480")
# Out:
# ['4561', '6405']

# %%
def get_postcode(x):
    """
    用正则表达式提取地址信息中的最后一个4位连续数字
    """
    pattern = r'\b\d{4}\b'
    if len(re.findall(pattern, x)) != 0:
        return re.findall(pattern, x)[-1]
    else:
        return None

# %%
whole["StartPostCode"] = whole["startAddress"].apply(get_postcode)
whole["EndPostCode"] = whole["endAddress"].apply(get_postcode)

# %%
print("Missing Start Postcode: {}".format(whole["StartPostCode"].isnull().sum()))
print("Missing End Postcode: {}".format(whole["EndPostCode"].isnull().sum()))
# Out:
# Missing Start Postcode: 371
# Missing End Postcode: 369

# %% [markdown]
# 通过探索，可以发现起点、终点缺失的邮编互不交叉。接下来尝试用booking记录里的经纬度信息逆编码获得地址，再填补一轮邮编。

# %%
missing_start = whole[(whole["BookingID"].notnull()) & (whole["StartPostCode"].isnull())]  # 选出booking子集中起点邮编缺失的记录
missing_end = whole[(whole["BookingID"].notnull()) & (whole["EndPostCode"].isnull())]  # 选出booking子集中终点邮编缺失的记录

# %%
missing_start.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 635904 to 1153019
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   partitionKey        163 non-null    object
#  1   user_pseudo_id      163 non-null    object
#  2   createdAt           163 non-null    object
#  3   startAddress        163 non-null    object
#  4   endAddress          163 non-null    object
#  5   tripEstimate        163 non-null    float64
#  6   BookingID           163 non-null    float64
#  7   BookingCreatedTime  163 non-null    object
#  8   PickUp_Latitude     163 non-null    float64
#  9   PickUp_Longitude    163 non-null    float64
#  10  DropOff_Latitude    163 non-null    float64
#  11  DropOff_Longitude   163 non-null    float64
#  12  DispatchStatus      163 non-null    object
#  13  StartPostCode       0 non-null      object
#  14  EndPostCode         163 non-null    object
# dtypes: float64(6), object(9)
# memory usage: 20.4+ KB

# %%
for idx in missing_start.index:
    g = geocoder.osm(whole.loc[idx, ['PickUp_Latitude','PickUp_Longitude']].to_list(), method='reverse')
    whole.loc[idx, 'startAddress'] = g.address

# %%
for idx in missing_end.index:
    g = geocoder.osm(whole.loc[idx, ['DropOff_Latitude','DropOff_Longitude']].to_list(), method='reverse')
    whole.loc[idx, 'endAddress'] = g.address

# %% [markdown]
# 经纬度逆编码完成，接下来再次进行一次正则表达式提取邮编的操作。

# %%
whole.loc[missing_start.index, "StartPostCode"] = whole.loc[missing_start.index, "startAddress"].apply(get_postcode)
whole.loc[missing_end.index, "EndPostCode"] = whole.loc[missing_end.index, "endAddress"].apply(get_postcode)

# %%
pd.set_option('display.max_colwidth',None)
missing = whole[(whole["StartPostCode"].isnull()|whole["EndPostCode"].isnull()) & whole["BookingID"].notnull()]
missing[["startAddress", "endAddress"]]
# Out:
#                                                                                                                    startAddress  \
# 738620                                                                        9 Springfield Cct, Cannonvale QLD 4802, Australia
# 765674                                      AB Marine, Shingley Drive, Airlie Beach, Whitsunday Regional, Queensland, Australia
#
Airlie Beach, Whitsunday Regional, Queensland, Australia
# 1054530                       New Zealand Ice Cream, Airlie Main Street, Airlie Beach, Whitsunday Regional, Queensland, Australia
# 1063498                                                                  Airlie Beach, Whitsunday Regional, Queensland, Australia
# 1072915                       New Zealand Ice Cream, Airlie Main Street, Airlie Beach, Whitsunday Regional, Queensland, Australia
# 1144312                                  The Garden Bar, Shingley Drive, Airlie Beach, Whitsunday Regional, Queensland, Australia
# Name: startAddress, dtype: object

# %%
start_null_index = missing[missing['StartPostCode'].isnull()].index
start_code = [4802, 4802, 4740, 3350, 4802, 4802, 4802, 4802, 4802, 4802, 4802]
j = 0
for idx in start_null_index:
    whole.loc[idx, 'StartPostCode'] = start_code[j]
    j += 1

# %%
missing[missing["EndPostCode"].isnull()  & (missing['endAddress'] != 'Victoria, Australia') ]["endAddress"]
# Out:
# 738620                                             McIntosh Drive, Cannonvale, Whitsunday Regional, Queensland, Australia
# 881904                   Bundaberg Airport, Childers Road, Kensington, Bundaberg, Bundaberg Region, Queensland, Australia
# 936159     Whitsunday Harbour, Eshelby Drive, Yachtsmans Paradise, Cannonvale, Whitsunday Regional, Queensland, Australia
# 1000864                                           Seaview Drive, Airlie Beach, Whitsunday Regional, Queensland, Australia
# 1131133                                              Lakeside Drive, Taroomball, Livingstone Shire, Queensland, Australia
# Name: endAddress, dtype: object

# %%
end_null_index = missing[(missing['EndPostCode'].isnull()) & (missing['endAddress'] != 'Victoria, Australia') ].index
end_code = [4802, 4670, 4802, 4802, 4703]
j = 0
for idx in end_null_index:
    whole.loc[idx, 'EndPostCode'] = end_code[j]
    j += 1

# %%
vic_au = missing[missing['endAddress'] == 'Victoria, Australia'].index.to_list()
whole.loc[vic_au, ['DropOff_Latitude', 'DropOff_Longitude']]#都是关于Port Phillip (Bay)
# Out:
#          DropOff_Latitude  DropOff_Longitude
# 845637         -38.081120         144.902353
# 1114210        -38.080515         144.889568

# %%
whole.loc[vic_au, 'EndPostCode'] = [3222, 3222]

# %%
whole.isnull().sum()
# Out:
# partitionKey               0
# user_pseudo_id             0
# createdAt                  0
# startAddress               0
# endAddress                 0
# tripEstimate               0
# BookingID             632086
# BookingCreatedTime    632086
# PickUp_Latitude       632086
# PickUp_Longitude      632086
# DropOff_Latitude      632086
# DropOff_Longitude     632086
# DispatchStatus        632086
# StartPostCode            208
# EndPostCode              240
# dtype: int64

# %%
whole[whole['BookingID'].notnull()].isnull().sum()
# Out:
# partitionKey          0
# user_pseudo_id        0
# createdAt             0
# startAddress          0
# endAddress            0
# tripEstimate          0
# BookingID             0
# BookingCreatedTime    0
# PickUp_Latitude       0
# PickUp_Longitude      0
# DropOff_Latitude      0
# DropOff_Longitude     0
# DispatchStatus        0
# StartPostCode         0
# EndPostCode           0
# dtype: int64

# %% [markdown]
# ### 3.1.2 行政州提取

# %%
def postcode_state(x):
    if 800<=x<=899 or 900<=x<=999:
        return "NT"
    elif 200<=x<=299 or 2600<=x<=2618 or 2900<=x<=2920:
        return "ACT"
    elif 1000<=x<=1999 or 2000<=x<=2599 or 2619<=x<=2899 or 2921<=x<=2999:
        return "NSW"
    elif 3000<=x<=3999 or 8000<=x<=8999:
        return "VIC"
    elif 4000<=x<=4999 or 9000<=x<=9999:
        return "QLD"
    elif 5000<=x<=5799 or 5800<=x<=5999:
        return "SA"
    elif 6000<=x<=6797 or 6800<=x<=6999:
        return "WA"
    elif 7000<=x<=7799 or 7800<=x<=7999:
        return "TAS"
    else:
        return None

# %%
whole.loc[whole["StartPostCode"].notnull(), "StartState"] = whole.loc[whole["StartPostCode"].notnull(), "StartPostCode"].astype(int).apply(postcode_state)
whole.loc[whole["EndPostCode"].notnull(), "EndState"] = whole.loc[whole["EndPostCode"].notnull(), "EndPostCode"].astype(int).apply(postcode_state)

# %%
whole[whole["BookingID"].notnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 519835 entries, 632260 to 1153632
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   partitionKey        519835 non-null  object
#  1   user_pseudo_id      519835 non-null  object
#  2   createdAt           519835 non-null  object
#  3   startAddress        519835 non-null  object
#  4   endAddress          519835 non-null  object
#  5   tripEstimate        519835 non-null  float64
#  6   BookingID           519835 non-null  float64
#  7   BookingCreatedTime  519835 non-null  object
#  8   PickUp_Latitude     519835 non-null  float64
#  9   PickUp_Longitude    519835 non-null  float64
#  10  DropOff_Latitude    519835 non-null  float64
#  11  DropOff_Longitude   519835 non-null  float64
#  12  DispatchStatus      519835 non-null  object
#  13  StartPostCode       519835 non-null  object
#  14  EndPostCode         519835 non-null  object
#  15  StartState          519835 non-null  object
#  16  EndState            519835 non-null  object
# dtypes: float64(6), object(11)
# memory usage: 71.4+ MB

# %% [markdown]
# ### 3.1.3 跨州判断

# %%
whole["CrossState"] = 1
whole.loc[whole["StartState"]==whole["EndState"], "CrossState"] = 0

# %%
whole["CrossState"].value_counts()
# Out:
# 0    1143118
# 1       8803
# Name: CrossState, dtype: int64

# %% [markdown]
# ## 3.2 时间类
# **准备工作：**
# * 把原数据集中的2个时间字段都**转化为datetime格式**；
# * 对BookingCreatedTime字段进行分箱，分别按照日内**半小时间隔**、周内**日间隔**进行分箱，提取出每条记录的预定创建时间的所在半小时数、所在周几。

# %%
whole["createdAt"] = pd.to_datetime(whole["createdAt"], format="%Y-%m-%d")
whole["BookingCreatedTime"] = pd.to_datetime(whole["BookingCreatedTime"], format="%Y-%m-%d")
whole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1151921 entries, 0 to 1153632
# Data columns (total 18 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   partitionKey        1151921 non-null  object
#  1   user_pseudo_id      1151921 non-null  object
#  2   createdAt           1151921 non-null  datetime64[ns]
#  3   startAddress        1151921 non-null  object
#  4   endAddress          1151921 non-null  object
#  5   tripEstimate        1151921 non-null  float64
#  6   BookingID           519835 non-null   float64
#  7   BookingCreatedTime  519835 non-null   datetime64[ns]
#  8   PickUp_Latitude     519835 non-null   float64
#  9   PickUp_Longitude    519835 non-null   float64
#  10  DropOff_Latitude    519835 non-null   float64
#  11  DropOff_Longitude   519835 non-null   float64
#  12  DispatchStatus      519835 non-null   object
#  13  StartPostCode       1151713 non-null  object
#  14  EndPostCode         1151681 non-null  object
#  15  StartState          1151713 non-null  object
#  16  EndState            1151681 non-null  object
#  17  CrossState          1151921 non-null  int64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(9)
# memory usage: 199.2+ MB

# %%
whole["DispatchStatus"] = whole["DispatchStatus"].replace(dict(NotCompleted=0, Completed=1))

# %%
whole["BookingCreatedHour"] = whole["BookingCreatedTime"].dt.hour
whole["BookingCreatedMin"] = whole["BookingCreatedTime"].dt.minute
whole["BookingCreatedDay"] = whole["BookingCreatedTime"].dt.weekday  # 0:周一，1:周二...以此类推
whole["BookingCreatedDate"] = whole["BookingCreatedTime"].dt.date
whole["BookingCreatedWeek"] =whole["BookingCreatedTime"].dt.week - 35

# %%
whole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1151921 entries, 0 to 1153632
# Data columns (total 23 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   partitionKey        1151921 non-null  object
#  1   user_pseudo_id      1151921 non-null  object
#  2   createdAt           1151921 non-null  datetime64[ns]
#  3   startAddress        1151921 non-null  object
#  4   endAddress          1151921 non-null  object
#  5   tripEstimate        1151921 non-null  float64
#  6   BookingID           519835 non-null   float64
#  7   BookingCreatedTime  519835 non-null   datetime64[ns]
#  8   PickUp_Latitude     519835 non-null   float64
#  9   PickUp_Longitude    519835 non-null   float64
#  10  DropOff_Latitude    519835 non-null   float64
#  11  DropOff_Longitude   519835 non-null   float64
#  12  DispatchStatus      519835 non-null   float64
#  13  StartPostCode       1151713 non-null  object
#  14  EndPostCode         1151681 non-null  object
#  15  StartState          1151713 non-null  object
#  16  EndState            1151681 non-null  object
#  17  CrossState          1151921 non-null  int64
#  18  BookingCreatedHour  519835 non-null   float64
#  19  BookingCreatedMin   519835 non-null   float64
#  20  BookingCreatedDay   519835 non-null   float64
#  21  BookingCreatedDate  519835 non-null   object
#  22  BookingCreatedWeek  519835 non-null   float64
# dtypes: datetime64[ns](2), float64(11), int64(1), object(9)
# memory usage: 243.2+ MB

# %%
# 这个代码块的目的是把时间分箱成半小时的间隔。作图可以先不用，因为48个间隔太拥挤了。但是模型可以尝试这个更小的分享间隔。
def MinuteConvert(x):
    if 0 <= x < 30:
        return 0
    elif x >= 30:
        return 0.5

whole["BookingCreatedAdd"] = whole["BookingCreatedMin"].apply(MinuteConvert)
whole["BookingCreatedAdd"] = whole["BookingCreatedAdd"] + whole["BookingCreatedHour"]

# %%
whole["BookingCreatedAdd"]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#            ...
# 1153628     9.0
# 1153629     6.5
# 1153630    11.5
# 1153631     9.5
# 1153632    11.5
# Name: BookingCreatedAdd, Length: 1151921, dtype: float64

# %%
# whole.to_csv('Assignment1_mmp.csv',index=False)

# %%
bookings = whole[whole["BookingCreatedAdd"].notnull()]

# %%
# 可以根据这个datetframe做日内时间的可视化
# DispatchStatus是成单数，Counts是总订单数，Rate是成单率

gb = bookings.groupby(["BookingCreatedDay", "BookingCreatedHour", "StartState"]).sum()["DispatchStatus"].reset_index()
gb["Counts"] = bookings.groupby(["BookingCreatedDay", "BookingCreatedHour", "StartState"]).count()["BookingID"].reset_index()["BookingID"]
gb["Rate"] = gb["DispatchStatus"] / gb["Counts"]
gb
# Out:
#       BookingCreatedDay  BookingCreatedHour StartState  DispatchStatus  \
# 0                   0.0                 0.0        NSW           187.0
# 1                   0.0                 0.0         NT             0.0
# 2                   0.0                 0.0        QLD           233.0
# 3                   0.0                 0.0         SA            20.0
# 4                   0.0                 0.0        VIC           210.0
# ...                 ...                 ...        ...             ...
# 997                 6.0                23.0         NT             2.0
# 998                 6.0                23.0        QLD           379.0
# 999                 6.0                23.0         SA            37.0
# 1000                6.0                23.0        VIC           330.0
# 1001                6.0                23.0         WA            48.0
#
#       Counts      Rate
# 0        394  0.474619
# 1          5  0.000000
# 2        537  0.433892
# 3         45  0.444444
# 4        444  0.472973
# ...      ...       ...
# 997        6  0.333333
# 998     1049  0.361296
# 999       76  0.486842
# 1000     727  0.453920
# 1001     109  0.440367
#
# [1002 rows x 6 columns]

# %%
g = whole[whole["BookingID"].notnull()].groupby(["CrossState","StartState","EndState"]).sum()["DispatchStatus"].reset_index()
g["Counts"] = whole[whole["BookingID"].notnull()].groupby(["CrossState","StartState","EndState"]).count().reset_index()["DispatchStatus"]
g["Rate"] = g["DispatchStatus"] / g["Counts"]
g
# Out:
#     CrossState StartState EndState  DispatchStatus  Counts      Rate
# 0            0        NSW      NSW        105022.0  152588  0.688272
# 1            0         NT       NT           559.0    1611  0.346989
# 2            0        QLD      QLD        105112.0  168361  0.624325
# 3            0         SA       SA         10074.0   15951  0.631559
# 4            0        VIC      VIC        113649.0  171215  0.663779
# 5            0         WA       WA          3706.0    8196  0.452172
# 6            1        NSW      QLD             6.0      19  0.315789
# 7            1        NSW      VIC           388.0     647  0.599691
# 8            1         NT      VIC             0.0       1  0.000000
# 9            1        QLD      NSW           119.0     396  0.300505
# 10           1        QLD       SA             0.0       2  0.000000
# 11           1        QLD      VIC             0.0       2  0.000000
# 12           1         SA      NSW             0.0       2  0.000000
# 13           1         SA      VIC             0.0       4  0.000000
# 14           1        VIC      ACT             0.0       3  0.000000
# 15           1        VIC      NSW           403.0     717  0.562064
# 16           1        VIC      QLD             0.0       4  0.000000
# 17           1        VIC       SA             1.0       5  0.200000
# 18           1         WA       NT             0.0       2  0.000000
# 19           1         WA      VIC            37.0     109  0.339450

# %%
bookings.groupby("CrossState").mean()["tripEstimate"]
# Out:
# CrossState
# 0    33.931130
# 1    95.710105
# Name: tripEstimate, dtype: float64

# %%
bookings["log_tripEstimate"] = np.log(bookings["tripEstimate"])

# %%
sns.kdeplot(data=bookings[bookings["CrossState"]==0],
            x="log_tripEstimate")
sns.kdeplot(data=bookings[bookings["CrossState"]==1],
            x="log_tripEstimate")
plt.show()

# %% [markdown]
# ### 3.2.1 日内周期性
# #### 估计价格（非聚类规律）

# %%
sns.kdeplot(data=bookings[bookings["DispatchStatus"]==0],
            x="tripEstimate")
sns.kdeplot(data=bookings[bookings["DispatchStatus"]==1],
            x="tripEstimate")
plt.show()

# %%
sns.boxplot(data=bookings,
            x="BookingCreatedHour",
            y="log_tripEstimate", color="lightblue",
            showfliers=False)
sns.stripplot(data=bookings[bookings["DispatchStatus"]==0],
              x="BookingCreatedHour",
              y="log_tripEstimate", size=2, linewidth=0,color="red",
              alpha=0.08)
sns.stripplot(data=bookings[bookings["DispatchStatus"]==1],
              x="BookingCreatedHour",
              y="log_tripEstimate", size=2, linewidth=0,color="b",
              alpha=0.08)

# plt.ylim(-10, 200)
plt.tight_layout()
plt.show()

# %%
whole[(whole["tripEstimate"] > 5000) & (whole["DispatchStatus"]==0)]
# Out:
#                                 partitionKey  \
# 977563  7f4b0990-4760-11ed-9661-47dabcf94230
# 982063  e0aedc60-4536-11ed-9661-47dabcf94230
# 984109  656951f0-585c-11ed-ab27-35d86fd49d36
# 984278  5b20ee00-36a2-11ed-9992-2bb9650dd4cf
# 985268  8cda22f0-4e11-11ed-9661-47dabcf94230
# 985473  d4ca9a50-2ba1-11ed-9a00-d5b713a64e81
#
#                           user_pseudo_id               createdAt  \
# 977563  E337EA5FD4DB49C69882FDBEF2CD12FB 2022-10-09 10:25:29.640
# 982063  ac173263661ea29de81b887601bb59f1 2022-10-06 16:22:32.253
# 984109  870751a9948227bde157a36e495a9dc7 2022-10-31 01:08:58.000
# 984278  F7BA7D3D15244D8695A1DB9E51513EAC 2022-09-18 02:04:05.983
# 985268  7F9325779B1644B498465285B7E9292B 2022-10-17 22:48:00.286
# 985473  24f001c8bdd712f5f6de682e2eac541d 2022-09-04 02:02:37.813
#
#                                                startAddress  \
# 977563       166 Adelaide Terrace, Perth WA 6004, Australia
# 982063           152 James St, New Farm QLD 4005, Australia
# 984109       100 Millot Vista, Caversham WA 6055, Australia
# 984278         2 Chelsea Cres, Glenella QLD 4740, Australia
# 985268  387-389 Pacific Hwy, Crows Nest NSW 2065, Australia
# 985473         7 The Strand, Townsville QLD 4810, Australia
#
#                                              endAddress  tripEstimate  \
# 977563    5 Arrival Dr, Tullamarine VIC 3045, Australia       6804.74
# 982063       4 Sargent St, New Farm QLD 4005, Australia       8602.65
# 984109       22 Monash St, Newstead VIC 3462, Australia       6582.45
# 984278        3 Tamlyn Ct, Greenwith SA 5125, Australia       5717.25
# 985268    31-45 Eyre St, North Ward QLD 4810, Australia       5746.34
# 985473  3/10 Gawler St, Mount Barker SA 5251, Australia       6311.03
#
#          BookingID      BookingCreatedTime  PickUp_Latitude  PickUp_Longitude  \
# 977563  32211141.0 2022-10-09 10:25:37.126       -31.959202        115.871448
# 982063  32142538.0 2022-10-06 16:22:37.856       -27.461591        153.046539
# 984109  32750731.0 2022-10-31 01:14:07.000       -31.864053        115.968607
# 984278  31728575.0 2022-09-18 02:04:16.330       -21.110672        149.149613
# 985268  32414329.0 2022-10-17 22:48:19.910       -33.829077        151.201875
# 985473  31405596.0 2022-09-04 02:02:40.423       -19.256865        146.824053
#
#         ...  DispatchStatus  StartState  EndState CrossState  \
# 977563  ...             0.0          WA       VIC          1
# 982063  ...             0.0         QLD       QLD          0
# 984109  ...             0.0          WA       VIC          1
# 984278  ...             0.0         QLD        SA          1
# 985268  ...             0.0         NSW       QLD          1
# 985473  ...             0.0         QLD        SA          1
#
#        BookingCreatedHour  BookingCreatedMin  BookingCreatedDay  \
# 977563               10.0               25.0                6.0
# 982063               16.0               22.0                3.0
# 984109                1.0               14.0                0.0
# 984278                2.0                4.0                6.0
# 985268               22.0               48.0                0.0
# 985473                2.0                2.0                6.0
#
#         BookingCreatedDate  BookingCreatedWeek BookingCreatedAdd
# 977563          2022-10-09                 5.0              10.0
# 982063          2022-10-06                 5.0              16.0
# 984109          2022-10-31                 9.0               1.0
# 984278          2022-09-18                 2.0               2.0
# 985268          2022-10-17                 7.0              22.5
# 985473          2022-09-04                 0.0               2.0
#
# [6 rows x 22 columns]

# %% [markdown]
# #### 总订单数（聚类规律）

# %%
sns.barplot(data=gb,
             x="BookingCreatedHour",
             y="Counts",
             )
plt.ylabel("Counts")
plt.xlabel("Hours")
plt.title("Average Bookings")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 完成单数（聚类规则）

# %%
sns.barplot(data=gb,
             x="BookingCreatedHour",
             y="DispatchStatus",
             )
plt.ylabel("Counts")
plt.xlabel("Hours")
plt.title("Average Completed Bookings")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 完成单率（聚类规律）

# %%
sns.lineplot(data=gb,
             x="BookingCreatedHour",
             y="Rate",
             hue="StartState"
             )
plt.ylabel("Completed Rate")
plt.xlabel("Hours")
plt.ylim(0,1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.2.2 周周期性

# %% [markdown]
# #### 估计价格（非聚类规律）

# %%
sns.boxplot(data=bookings,
            x="BookingCreatedDay",
            y="log_tripEstimate", color="lightblue",
            showfliers=False)
# sns.stripplot(data=bookings[bookings["DispatchStatus"]==0],
#               x="BookingCreatedHour",
#               y="tripEstimate", size=2, linewidth=0,color="red",
#               alpha=0.08)
# sns.stripplot(data=bookings[bookings["DispatchStatus"]==1],
#               x="BookingCreatedHour",
#               y="tripEstimate", size=2, linewidth=0,color="b",
#               alpha=0.08)

# plt.ylim(-10, 200)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 总订单数（聚类规律）

# %%
sns.barplot(data=gb,
             x="BookingCreatedDay",
             y="Counts",
             )
plt.ylabel("Counts")
plt.xlabel("Weekdays")
plt.title("Average Bookings")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 完成单数（聚类规律）

# %%
sns.barplot(data=gb,
             x="BookingCreatedDay",
             y="DispatchStatus",
             )
plt.ylabel("Counts")
plt.xlabel("Weekdays")
plt.title("Average Completed Bookings")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 完成单率（聚类规律）

# %%
sns.lineplot(data=gb,
             x="BookingCreatedDay",
             y="Rate",
             )
plt.ylabel("Completed Rate")
plt.xlabel("Weekdays")
plt.ylim(0,1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.3 用户类

# %% [markdown]
# ### 3.3.1 近7日查询次数

# %%
whole["CompletedValue"] = whole["tripEstimate"] * whole["DispatchStatus"]

# %%
columns = ["partitionKey", "createdAt", "user_pseudo_id", "BookingID", "DispatchStatus", "CompletedValue"]
rolling = whole[columns].sort_values("createdAt",ascending=True).groupby(["user_pseudo_id"]).rolling(window="7D", on="createdAt", closed="left")
aggregate = pd.DataFrame()
aggregate[["LookingUpCounts_past7D","BookingCounts_past7D"]] = rolling.count()[["partitionKey","BookingID"]]
aggregate[["BookingCompleted_past7D", "CompletedValue_past7D"]] = rolling.sum()[["DispatchStatus","CompletedValue"]]
aggregate
# Out:
#                                           LookingUpCounts_past7D  \
# user_pseudo_id
# 000007C65F114B2594E6A2126765A295 626649                      NaN
#                                  14922                       1.0
#                                  916199                      NaN
#                                  1063582                     1.0
#                                  863637                      2.0
# ...                                                          ...
# ffff96013007c74dca8b111fdba920c9 836676                      2.0
#                                  1055165                     3.0
#                                  853212                      2.0
#                                  835836                      2.0
#                                  837191                      NaN
#
#                                           BookingCounts_past7D  \
# user_pseudo_id
# 000007C65F114B2594E6A2126765A295 626649                    NaN
#                                  14922                     0.0
#                                  916199                    NaN
#                                  1063582                   1.0
#                                  863637                    2.0
# ...                                                        ...
# ffff96013007c74dca8b111fdba920c9 836676                    1.0
#                                  1055165                   2.0
#                                  853212                    2.0
#                                  835836                    2.0
#                                  837191                    NaN
#
#                                           BookingCompleted_past7D  \
# user_pseudo_id
# 000007C65F114B2594E6A2126765A295 626649                       NaN
#                                  14922                        NaN
#                                  916199                       NaN
#                                  1063582                      1.0
#                                  863637                       1.0
# ...                                                           ...
# ffff96013007c74dca8b111fdba920c9 836676                       0.0
#                                  1055165                      1.0
#                                  853212                       1.0
#                                  835836                       1.0
#                                  837191                       NaN
#
#                                           CompletedValue_past7D
# user_pseudo_id
# 000007C65F114B2594E6A2126765A295 626649                     NaN
#                                  14922                      NaN
#                                  916199                     NaN
#                                  1063582                  13.34
#                                  863637                   13.34
# ...                                                         ...
# ffff96013007c74dca8b111fdba920c9 836676                    0.00
#                                  1055165                  23.84
#                                  853212                   23.84
#                                  835836                   23.63
#                                  837191                     NaN
#
# [1151919 rows x 4 columns]

# %%
agg = aggregate.reset_index(level=0).fillna(0)
agg
# Out:
#                            user_pseudo_id  LookingUpCounts_past7D  \
# 626649   000007C65F114B2594E6A2126765A295                     0.0
# 14922    000007C65F114B2594E6A2126765A295                     1.0
# 916199   000007C65F114B2594E6A2126765A295                     0.0
# 1063582  000007C65F114B2594E6A2126765A295                     1.0
# 863637   000007C65F114B2594E6A2126765A295                     2.0
# ...                                   ...                     ...
# 836676   ffff96013007c74dca8b111fdba920c9                     2.0
# 1055165  ffff96013007c74dca8b111fdba920c9                     3.0
# 853212   ffff96013007c74dca8b111fdba920c9                     2.0
# 835836   ffff96013007c74dca8b111fdba920c9                     2.0
# 837191   ffff96013007c74dca8b111fdba920c9                     0.0
#
#          BookingCounts_past7D  BookingCompleted_past7D  CompletedValue_past7D
# 626649                    0.0                      0.0                   0.00
# 14922                     0.0                      0.0                   0.00
# 916199                    0.0                      0.0                   0.00
# 1063582                   1.0                      1.0                  13.34
# 863637                    2.0                      1.0                  13.34
# ...                       ...                      ...                    ...
# 836676                    1.0                      0.0                   0.00
# 1055165                   2.0                      1.0                  23.84
# 853212                    2.0                      1.0                  23.84
# 835836                    2.0                      1.0                  23.63
# 837191                    0.0                      0.0                   0.00
#
# [1151919 rows x 5 columns]

# %%
new = pd.merge(whole, agg, how="left", left_index=True, right_index=True)
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1151919 entries, 0 to 1153632
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   partitionKey             1151919 non-null  object
#  1   user_pseudo_id_x         1151919 non-null  object
#  2   createdAt                1151919 non-null  datetime64[ns]
#  3   startAddress             1151919 non-null  object
#  4   endAddress               1151919 non-null  object
#  5   tripEstimate             1151919 non-null  float64
#  6   BookingID                519835 non-null   float64
#  7   BookingCreatedTime       519835 non-null   datetime64[ns]
#  8   PickUp_Latitude          519835 non-null   float64
#  9   PickUp_Longitude         519835 non-null   float64
#  10  DropOff_Latitude         519835 non-null   float64
#  11  DropOff_Longitude        519835 non-null   float64
#  12  DispatchStatus           519835 non-null   float64
#  13  StartState               1151919 non-null  object
#  14  EndState                 1151919 non-null  object
#  15  CrossState               1151919 non-null  int64
#  16  StartPostCode            1151721 non-null  object
#  17  EndPostCode              1151695 non-null  object
#  18  BookingCreatedHour       519835 non-null   float64
#  19  BookingCreatedMin        519835 non-null   float64
#  20  BookingCreatedDay        519835 non-null   float64
#  21  BookingCreatedDate       519835 non-null   object
#  22  BookingCreatedWeek       519835 non-null   float64
#  23  BookingCreatedAdd        519835 non-null   float64
#  24  CompletedValue           519835 non-null   float64
#  25  user_pseudo_id_y         1151919 non-null  object
#  26  LookingUpCounts_past7D   1151919 non-null  float64
#  27  BookingCounts_past7D     1151919 non-null  float64
#  28  BookingCompleted_past7D  1151919 non-null  float64
#  29  CompletedValue_past7D    1151919 non-null  float64
# dtypes: datetime64[ns](2), float64(17), int64(1), object(10)
# memory usage: 304.7+ MB

# %%
demo["BookingCompletedBins"] = demo["BookingCompleted_past7D"].apply(lambda x: x if x<=20 else 11)

# %%
demo["BookingCompletedRate_past7D"] = demo["BookingCompleted_past7D"] / demo["BookingCounts_past7D"]

# %%
sns.scatterplot(data=demo,
                y="BookingCompletedRate_past7D",
                x="BookingCounts_past7D",
                hue="DispatchStatus",
                alpha=0.4)
plt.show()

# %%
df = demo.groupby(["BookingCompleted_past7D", "BookingCreatedHour", "StartState"]).sum()["DispatchStatus"].reset_index()
df["BookingCounts"] = demo.groupby(["BookingCompleted_past7D", "BookingCreatedHour", "StartState"]).count()["DispatchStatus"].reset_index()["DispatchStatus"]
df["Rate"] = df["DispatchStatus"] / df["BookingCounts"]
df
# Out:
#       BookingCompleted_past7D  BookingCreatedHour StartState  DispatchStatus  \
# 0                         0.0                 0.0  Coral Sea             7.0
# 1                         0.0                 0.0        NSW          1240.0
# 2                         0.0                 0.0         NT             3.0
# 3                         0.0                 0.0        QLD          1423.0
# 4                         0.0                 0.0         SA           139.0
# ...                       ...                 ...        ...             ...
# 2237                     46.0                 3.0        VIC             1.0
# 2238                     46.0                14.0        VIC             1.0
# 2239                     46.0                22.0        VIC             1.0
# 2240                     46.0                23.0        VIC             0.0
# 2241                     47.0                20.0        VIC             1.0
#
#       BookingCounts      Rate
# 0                 7  1.000000
# 1              2312  0.536332
# 2                33  0.090909
# 3              3026  0.470258
# 4               247  0.562753
# ...             ...       ...
# 2237              3  0.333333
# 2238              1  1.000000
# 2239              1  1.000000
# 2240              1  0.000000
# 2241              2  0.500000
#
# [2242 rows x 6 columns]

# %%
sns.lineplot(data=df,
             x="BookingCompleted_past7D",
             y="Rate",

)
plt.ylim(0,1)
plt.show()

# %%
df = demo[["BookingCompletedBins", "DispatchStatus"]].groupby("BookingCompletedBins").sum() / demo[["BookingCompletedBins", "DispatchStatus"]].groupby("BookingCompletedBins").count()
plt.plot(df["DispatchStatus"].values)
plt.ylim(0,1)
plt.show()

# %% [markdown]
# ### 3.3.2 近7日预订次数

# %% [markdown]
# ### 3.3.3 近7日预订完成率
